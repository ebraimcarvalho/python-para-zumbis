# %% [markdown]
# # EP Estrutura de Dados Merlin
# *Link do drive completo: https://www.dropbox.com/sh/m9wio7ock77yowd/AAAR3ogXRJqhd5Uw3NthvS0Ia?dl=0*

# %%
def enumerações(items):
    n = len(items)
    s = [0]*(n+1)
    k = 0
    while True:
        if s[k] < n:
            s[k+1] = s[k] + 1
            k += 1
        else:
            s[k-1] += 1
            k -= 1
        if k == 0:
            break
        else:
            lista = []
            for j in range(1, k+1):
                lista.append(items[s[j]-1])
            yield lista

def combinações(items, n):
    if n==0: yield []
    else:
        for i in range(len(items)):
            for cc in combinações(items[:i]+items[i+1:],n-1):
                yield [items[i]]+cc

def permutações(items):
    return combinações(items, len(items))

#troque o código abaixo pela sua implementação
#faça a leitura de casamento.txt e cavaleiros.txt
#e monte os dicionários de amados e amigos
#depois implemente sua lógica para dizer se é possível
#o casamento e sentar na mesa sem brigar, não é necessário
#mostrar o casamento concreto possível
print ('Permutações')
for p in permutações(['Adriano','Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Leandro', 'Walber']):
    print (p)

print ('Enumerações')
for p in enumerações(['Jessica', 'Fernanda', 'Pamela', 'Renata']):
    print (p)
# Out:
# Permutações
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Eclis', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Leandro', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Diogo', 'Walber', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Diogo', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Leandro', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Eclis', 'Walber', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Leandro', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Eclis', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Eclis', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Leandro', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Gabriel', 'Walber', 'Leandro', 'Eclis', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Diogo', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Eclis', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Gabriel', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Diogo', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Diogo', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Eclis', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Eclis', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Gabriel', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Leandro', 'Walber', 'Gabriel', 'Eclis', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Diogo', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Eclis', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Eclis', 'Diogo', 'Leandro']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Eclis', 'Leandro', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Leandro', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Gabriel', 'Leandro', 'Eclis', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Diogo', 'Eclis', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Diogo', 'Gabriel', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Eclis', 'Diogo', 'Gabriel']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Eclis', 'Gabriel', 'Diogo']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Gabriel', 'Diogo', 'Eclis']
# ['Adriano', 'Bruno', 'Walber', 'Leandro', 'Gabriel', 'Eclis', 'Diogo']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Eclis', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Leandro', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Bruno', 'Walber', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Bruno', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Leandro', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Eclis', 'Walber', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Leandro', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Bruno', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Bruno', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Eclis', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Eclis', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Leandro', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Gabriel', 'Walber', 'Leandro', 'Eclis', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Bruno', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Eclis', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Gabriel', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Bruno', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Bruno', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Eclis', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Eclis', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Gabriel', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Leandro', 'Walber', 'Gabriel', 'Eclis', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Bruno', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Eclis', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Bruno', 'Eclis', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Bruno', 'Leandro', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Eclis', 'Bruno', 'Leandro']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Eclis', 'Leandro', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Leandro', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Gabriel', 'Leandro', 'Eclis', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Bruno', 'Eclis', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Bruno', 'Gabriel', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Eclis', 'Bruno', 'Gabriel']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Eclis', 'Gabriel', 'Bruno']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Gabriel', 'Bruno', 'Eclis']
# ['Adriano', 'Diogo', 'Walber', 'Leandro', 'Gabriel', 'Eclis', 'Bruno']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Diogo', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Leandro', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Bruno', 'Walber', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Gabriel', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Gabriel', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Leandro', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Leandro', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Walber', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Bruno', 'Walber', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Leandro', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Diogo', 'Walber', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Leandro', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Bruno', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Bruno', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Diogo', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Diogo', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Leandro', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Gabriel', 'Walber', 'Leandro', 'Diogo', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Bruno', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Diogo', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Gabriel', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Bruno', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Bruno', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Diogo', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Diogo', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Gabriel', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Leandro', 'Walber', 'Gabriel', 'Diogo', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Bruno', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Diogo', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Bruno', 'Diogo', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Bruno', 'Leandro', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Diogo', 'Bruno', 'Leandro']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Diogo', 'Leandro', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Leandro', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Gabriel', 'Leandro', 'Diogo', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Bruno', 'Diogo', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Bruno', 'Gabriel', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Diogo', 'Bruno', 'Gabriel']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Diogo', 'Gabriel', 'Bruno']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Gabriel', 'Bruno', 'Diogo']
# ['Adriano', 'Eclis', 'Walber', 'Leandro', 'Gabriel', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Leandro', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Eclis', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Eclis', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Leandro', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Bruno', 'Walber', 'Leandro', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Leandro', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Leandro', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Walber', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Walber', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Leandro', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Bruno', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Bruno', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Eclis', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Eclis', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Leandro', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Diogo', 'Walber', 'Leandro', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Leandro', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Leandro', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Walber', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Walber', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Leandro', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Walber', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Leandro', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Leandro', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Walber', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Walber', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Leandro', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Bruno', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Bruno', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Diogo', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Diogo', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Leandro', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Eclis', 'Walber', 'Leandro', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Bruno', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Diogo', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Eclis', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Bruno', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Bruno', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Diogo', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Diogo', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Eclis', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Leandro', 'Walber', 'Eclis', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Eclis', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Eclis', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Leandro', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Bruno', 'Leandro', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Bruno', 'Eclis', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Bruno', 'Leandro', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Eclis', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Eclis', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Leandro', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Diogo', 'Leandro', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Bruno', 'Diogo', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Bruno', 'Leandro', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Diogo', 'Bruno', 'Leandro']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Diogo', 'Leandro', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Leandro', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Eclis', 'Leandro', 'Diogo', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Bruno', 'Diogo', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Bruno', 'Eclis', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Diogo', 'Bruno', 'Eclis']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Diogo', 'Eclis', 'Bruno']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Eclis', 'Bruno', 'Diogo']
# ['Adriano', 'Gabriel', 'Walber', 'Leandro', 'Eclis', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Diogo', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Eclis', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Gabriel', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Diogo', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Diogo', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Eclis', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Eclis', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Gabriel', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Bruno', 'Walber', 'Gabriel', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Gabriel', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Gabriel', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Walber', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Bruno', 'Walber', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Eclis', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Gabriel', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Bruno', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Bruno', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Eclis', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Eclis', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Gabriel', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Diogo', 'Walber', 'Gabriel', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Gabriel', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Gabriel', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Walber', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Bruno', 'Walber', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Gabriel', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Walber', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Gabriel', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Gabriel', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Walber', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Diogo', 'Walber', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Gabriel', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Bruno', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Bruno', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Diogo', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Diogo', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Gabriel', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Eclis', 'Walber', 'Gabriel', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Diogo', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Eclis', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Walber', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Bruno', 'Walber', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Bruno', 'Walber', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Eclis', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Walber', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Diogo', 'Walber', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Bruno', 'Walber', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Walber']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Diogo', 'Walber', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Walber', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Eclis', 'Walber', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Bruno', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Bruno', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Diogo', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Diogo', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Eclis', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Gabriel', 'Walber', 'Eclis', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Diogo', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Diogo', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Eclis', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Eclis', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Gabriel', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Bruno', 'Gabriel', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Bruno', 'Eclis', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Bruno', 'Gabriel', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Eclis', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Eclis', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Gabriel', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Diogo', 'Gabriel', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Bruno', 'Diogo', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Bruno', 'Gabriel', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Diogo', 'Bruno', 'Gabriel']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Diogo', 'Gabriel', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Gabriel', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Eclis', 'Gabriel', 'Diogo', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Bruno', 'Diogo', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Bruno', 'Eclis', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Diogo', 'Bruno', 'Eclis']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Diogo', 'Eclis', 'Bruno']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Eclis', 'Bruno', 'Diogo']
# ['Adriano', 'Leandro', 'Walber', 'Gabriel', 'Eclis', 'Diogo', 'Bruno']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Diogo', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Eclis', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Eclis', 'Diogo', 'Leandro']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Eclis', 'Leandro', 'Diogo']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Leandro', 'Diogo', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Gabriel', 'Leandro', 'Eclis', 'Diogo']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Diogo', 'Eclis', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Diogo', 'Gabriel', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Eclis', 'Diogo', 'Gabriel']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Eclis', 'Gabriel', 'Diogo']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Gabriel', 'Diogo', 'Eclis']
# ['Adriano', 'Walber', 'Bruno', 'Leandro', 'Gabriel', 'Eclis', 'Diogo']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Eclis', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Eclis', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Gabriel', 'Eclis', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Gabriel', 'Leandro', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Leandro', 'Eclis', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Bruno', 'Leandro', 'Gabriel', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Eclis', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Bruno', 'Eclis', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Bruno', 'Leandro', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Eclis', 'Bruno', 'Leandro']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Eclis', 'Leandro', 'Bruno']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Leandro', 'Bruno', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Gabriel', 'Leandro', 'Eclis', 'Bruno']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Bruno', 'Eclis', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Bruno', 'Gabriel', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Eclis', 'Bruno', 'Gabriel']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Eclis', 'Gabriel', 'Bruno']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Gabriel', 'Bruno', 'Eclis']
# ['Adriano', 'Walber', 'Diogo', 'Leandro', 'Gabriel', 'Eclis', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Diogo', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Diogo', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Gabriel', 'Diogo', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Gabriel', 'Leandro', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Leandro', 'Diogo', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Bruno', 'Leandro', 'Gabriel', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Bruno', 'Gabriel', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Bruno', 'Leandro', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Gabriel', 'Bruno', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Gabriel', 'Leandro', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Leandro', 'Bruno', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Diogo', 'Leandro', 'Gabriel', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Bruno', 'Diogo', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Bruno', 'Leandro', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Diogo', 'Bruno', 'Leandro']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Diogo', 'Leandro', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Leandro', 'Bruno', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Gabriel', 'Leandro', 'Diogo', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Bruno', 'Diogo', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Bruno', 'Gabriel', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Diogo', 'Bruno', 'Gabriel']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Diogo', 'Gabriel', 'Bruno']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Gabriel', 'Bruno', 'Diogo']
# ['Adriano', 'Walber', 'Eclis', 'Leandro', 'Gabriel', 'Diogo', 'Bruno']
# ['Adriano', 'Walber', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Leandro']
# ['Adriano', 'Walber', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Eclis']
# ['Adriano', 'Walber', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Leandro']
# ...
# ['Walber', 'Gabriel', 'Adriano', 'Leandro', 'Diogo', 'Bruno', 'Eclis']
# ['Walber', 'Gabriel', 'Adriano', 'Leandro', 'Diogo', 'Eclis', 'Bruno']
# ['Walber', 'Gabriel', 'Adriano', 'Leandro', 'Eclis', 'Bruno', 'Diogo']
# ['Walber', 'Gabriel', 'Adriano', 'Leandro', 'Eclis', 'Diogo', 'Bruno']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Diogo', 'Eclis', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Diogo', 'Leandro', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Eclis', 'Diogo', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Eclis', 'Leandro', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Leandro', 'Diogo', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Adriano', 'Leandro', 'Eclis', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Adriano', 'Eclis', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Adriano', 'Leandro', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Diogo', 'Leandro', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Adriano', 'Diogo', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Adriano', 'Leandro', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Leandro', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Eclis', 'Leandro', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Adriano', 'Diogo', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Adriano', 'Eclis', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Diogo', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Diogo', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Eclis', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Bruno', 'Leandro', 'Eclis', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Bruno', 'Eclis', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Bruno', 'Leandro', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Eclis', 'Bruno', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Eclis', 'Leandro', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Leandro', 'Bruno', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Adriano', 'Leandro', 'Eclis', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Adriano', 'Eclis', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Adriano', 'Leandro', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Leandro', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Bruno', 'Leandro', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Adriano', 'Bruno', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Adriano', 'Leandro', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Leandro', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Eclis', 'Leandro', 'Bruno', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Adriano', 'Bruno', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Adriano', 'Eclis', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Bruno', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Bruno', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Eclis', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Diogo', 'Leandro', 'Eclis', 'Bruno', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Bruno', 'Diogo', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Bruno', 'Leandro', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Diogo', 'Bruno', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Diogo', 'Leandro', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Leandro', 'Bruno', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Adriano', 'Leandro', 'Diogo', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Adriano', 'Diogo', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Adriano', 'Leandro', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Leandro', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Bruno', 'Leandro', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Adriano', 'Bruno', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Adriano', 'Leandro', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Adriano', 'Leandro']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Leandro', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Leandro', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Diogo', 'Leandro', 'Bruno', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Adriano', 'Bruno', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Adriano', 'Diogo', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Bruno', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Bruno', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Diogo', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Eclis', 'Leandro', 'Diogo', 'Bruno', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Bruno', 'Diogo', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Bruno', 'Eclis', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Diogo', 'Bruno', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Diogo', 'Eclis', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Eclis', 'Bruno', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Adriano', 'Eclis', 'Diogo', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Adriano', 'Diogo', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Adriano', 'Eclis', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Diogo', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Eclis', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Adriano', 'Bruno', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Adriano', 'Eclis', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Bruno', 'Adriano', 'Eclis']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Eclis', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Adriano', 'Bruno', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Adriano', 'Diogo', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Bruno', 'Adriano', 'Diogo']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Adriano']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Diogo', 'Adriano', 'Bruno']
# ['Walber', 'Gabriel', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Diogo', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Diogo', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Eclis', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Eclis', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Gabriel', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Bruno', 'Gabriel', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Bruno', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Bruno', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Eclis', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Eclis', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Gabriel', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Diogo', 'Gabriel', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Bruno', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Bruno', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Diogo', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Diogo', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Gabriel', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Eclis', 'Gabriel', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Bruno', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Bruno', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Diogo', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Diogo', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Eclis', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Adriano', 'Gabriel', 'Eclis', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Diogo', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Diogo', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Eclis', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Eclis', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Gabriel', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Adriano', 'Gabriel', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Adriano', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Adriano', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Eclis', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Gabriel', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Diogo', 'Gabriel', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Adriano', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Adriano', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Diogo', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Gabriel', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Eclis', 'Gabriel', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Adriano', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Adriano', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Diogo', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Diogo', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Eclis', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Bruno', 'Gabriel', 'Eclis', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Bruno', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Bruno', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Eclis', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Eclis', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Gabriel', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Adriano', 'Gabriel', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Adriano', 'Eclis', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Adriano', 'Gabriel', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Eclis', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Gabriel', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Bruno', 'Gabriel', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Adriano', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Adriano', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Bruno', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Gabriel', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Eclis', 'Gabriel', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Adriano', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Adriano', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Bruno', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Bruno', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Eclis', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Diogo', 'Gabriel', 'Eclis', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Bruno', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Bruno', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Diogo', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Diogo', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Gabriel', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Adriano', 'Gabriel', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Adriano', 'Diogo', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Adriano', 'Gabriel', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Diogo', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Gabriel', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Bruno', 'Gabriel', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Adriano', 'Bruno', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Adriano', 'Gabriel', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Adriano', 'Gabriel']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Bruno', 'Gabriel', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Gabriel', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Diogo', 'Gabriel', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Adriano', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Adriano', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Bruno', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Bruno', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Diogo', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Eclis', 'Gabriel', 'Diogo', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Bruno', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Bruno', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Diogo', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Diogo', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Eclis', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Adriano', 'Eclis', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Adriano', 'Diogo', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Adriano', 'Eclis', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Diogo', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Diogo', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Eclis', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Bruno', 'Eclis', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Adriano', 'Bruno', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Adriano', 'Eclis', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Bruno', 'Adriano', 'Eclis']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Bruno', 'Eclis', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Eclis', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Diogo', 'Eclis', 'Bruno', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Adriano', 'Bruno', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Adriano', 'Diogo', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Bruno', 'Adriano', 'Diogo']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Bruno', 'Diogo', 'Adriano']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Diogo', 'Adriano', 'Bruno']
# ['Walber', 'Leandro', 'Gabriel', 'Eclis', 'Diogo', 'Bruno', 'Adriano']
# Enumerações
# ['Jessica']
# ['Jessica', 'Fernanda']
# ['Jessica', 'Fernanda', 'Pamela']
# ['Jessica', 'Fernanda', 'Pamela', 'Renata']
# ['Jessica', 'Fernanda', 'Renata']
# ['Jessica', 'Pamela']
# ['Jessica', 'Pamela', 'Renata']
# ['Jessica', 'Renata']
# ['Fernanda']
# ['Fernanda', 'Pamela']
# ['Fernanda', 'Pamela', 'Renata']
# ['Fernanda', 'Renata']
# ['Pamela']
# ['Pamela', 'Renata']
# ['Renata']
